# %% [markdown]
# <a href="https://colab.research.google.com/github/jmuryawan/sparcs_descriptive_2022/blob/main/sparcs_descriptive_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sparcs-2022.csv')
# Out:
# <ipython-input-5-ebd8a75d188e>:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/sparcs-2022.csv')

# %%
# extracting relevant columns
df1 = df[['Age Group','Gender','Length of Stay','Total Charges','Total Costs', 'Type of Admission']]

# %%
df1
# Out:
#           Age Group Gender Length of Stay Total Charges Total Costs  \
# 0          50 to 69      F              3     51,514.62    7,552.54
# 1          18 to 29      M              1     25,370.86    3,469.55
# 2          18 to 29      F              2     23,876.78    6,180.33
# 3          18 to 29      F              2     43,319.05   12,588.93
# 4          18 to 29      M              4     40,266.23   10,355.99
# ...             ...    ...            ...           ...         ...
# 153377  70 or Older      F              3     94,611.15   22,795.78
# 153378     30 to 49      F              2     41,431.32    8,657.73
# 153379  70 or Older      F              1     26,199.15    4,338.53
# 153380     30 to 49      M              3     57,470.92   10,726.04
# 153381     50 to 69      F            NaN           NaN         NaN
#
#        Type of Admission
# 0              Emergency
# 1              Emergency
# 2                 Urgent
# 3               Elective
# ...

# %%
## basic descriptive statistics ##

# %%
# length of stay
# converting length of stay to numeric first
df1['Length of Stay'] = pd.to_numeric(df1['Length of Stay'], errors='coerce')
df1['Length of Stay'].describe()
# Out:
# <ipython-input-9-be05d8dd582c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Length of Stay'] = pd.to_numeric(df1['Length of Stay'], errors='coerce')
# count    153221.000000
# mean          6.035491
# std           8.581517
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           7.000000
# max         119.000000
# Name: Length of Stay, dtype: float64

# %%
# total charges
# converting total charges to numeric first
df1['Total Charges'] = pd.to_numeric(df1['Total Charges'], errors='coerce')
df1['Total Charges'].describe()
# Out:
# <ipython-input-10-ad03c7ce1174>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Total Charges'] = pd.to_numeric(df1['Total Charges'], errors='coerce')
# count     65.000000
# mean     656.925538
# std      315.463649
# min       32.280000
# 25%      348.140000
# 50%      795.160000
# 75%      928.790000
# max      995.000000
# Name: Total Charges, dtype: float64

# %%
# total costs
# converting total costs to numeric first
df1['Total Costs'] = pd.to_numeric(df1['Total Costs'], errors='coerce')
df1['Total Costs'].describe()
# Out:
# <ipython-input-11-1214152835e9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Total Costs'] = pd.to_numeric(df1['Total Costs'], errors='coerce')
# count    2102.000000
# mean      777.064738
# std       179.691634
# min         9.010000
# 25%       661.500000
# 50%       821.500000
# 75%       925.590000
# max       999.950000
# Name: Total Costs, dtype: float64

# %%
## categorical values ##

# %%
# age group
df1['Age Group'].value_counts()
# Out:
# Age Group
# 70 or Older    44819
# 50 to 69       41379
# 30 to 49       31395
# 0 to 17        21759
# 18 to 29       14030
# Name: count, dtype: int64

# %%
age_group_counts = df1['Age Group'].value_counts()
age_group_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Distribution of Age Groups')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
# gender
df1['Gender'].value_counts()
# Out:
# Gender
# F    84100
# M    69264
# U       18
# Name: count, dtype: int64

# %%
gender_counts = df1['Gender'].value_counts()
gender_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Genders')
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %%
# type of admission
df1['Type of Admission'].value_counts()
# Out:
# Type of Admission
# Emergency        104296
# Elective          24716
# Newborn           14415
# Urgent             9309
# Trauma              607
# Not Available        38
# Name: count, dtype: int64

# %%
admission_counts = df1['Type of Admission'].value_counts()
admission_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Type of Admission')
plt.ylabel('Count')
plt.title('Distribution of Admission Types')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability if necessary
plt.tight_layout()
plt.show()

# %%
## visualizations ##

# %%
# histogram for length of stay
sns.histplot(data=df1, x='Length of Stay')
plt.title('Distribution of Length of Stay')
plt.xlabel('Length of Stay')
plt.ylabel('Frequency')
plt.show()

# %%
# boxplot for total charges
sns.boxplot(data=df1, y='Total Charges')
plt.title('Boxplot of Total Charges')
plt.ylabel('Total Charges')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# bar plot for type of admission
sns.countplot(data=df1, x='Type of Admission')
plt.title('Distribution of Admission Types')
plt.xlabel('Type of Admission')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
## handling missing data ##

# %%
missing = df1.isnull().sum()
print(missing)
# Out:
# Age Group                 0
# Gender                    0
# Length of Stay          161
# Total Charges        153317
# Total Costs          151280
# Type of Admission         1
# dtype: int64

# %%
df1.dropna()
# Out:
#           Age Group Gender  Length of Stay  Total Charges  Total Costs  \
# 23458      30 to 49      F             2.0          75.00        65.50
# 24283       0 to 17      F             1.0         640.70       275.15
# 24337       0 to 17      F             1.0         787.65       338.26
# 24485       0 to 17      F             1.0         795.16       341.49
# 24617       0 to 17      M             1.0         948.15       407.19
# 28883       0 to 17      F             1.0         799.00       300.51
# 30422       0 to 17      F             1.0         864.67       883.42
# 52623       0 to 17      F             1.0         809.00       849.47
# 75821       0 to 17      M             1.0         937.50       402.61
# 75827       0 to 17      M             1.0         901.64       387.21
# 75845       0 to 17      F             1.0         831.11       356.92
# 76198       0 to 17      M             1.0         783.19       336.34
# ...

# %% [markdown]
# Summary Report
#
# *   What is the average length of stay?
#
# 6.035491 days
#
# *   How does the total cost vary by age group or type of admission?
#
# Overall, the average total cost does not vary much by age group, especially for those aged 1-69. However, for those aged 70+, the cost is much lower compared to other age groups.
#
# *   Any noticeable trends in admissions or charges?
#
# The most frequent type of admissions are emergencies, while the least frequent type is urgent.

# %%
age_group_costs = df1.groupby('Age Group')['Total Costs'].mean()
print(age_group_costs)
# Out:
# Age Group
# 0 to 17        782.104341
# 18 to 29       734.179091
# 30 to 49       724.181928
# 50 to 69       752.333651
# 70 or Older    562.429231
# Name: Total Costs, dtype: float64

# %%
age_group_costs.plot(kind='bar', color='skyblue')
plt.xlabel('Age Group')
plt.ylabel('Average Total Cost')
plt.title('Average Total Cost by Age Group')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
